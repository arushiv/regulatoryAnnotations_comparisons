# %%
import pandas
import sys
sys.path.insert(0, '/home/arushiv/toolScripts/SeabornCustomGrid/')
# %load_ext autoreload
# %autoreload 2
from plot_utils import makeGrid
import matplotlib.pyplot as plt
sys.path.insert(0, '/lab/work/arushiv/regulatoryAnnotations_comparisons/histone_info_content/scripts/')
from calculate_avgPosteriors import  calculate_information
import math
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
denh = pandas.read_csv("/lab/work/arushiv/regulatoryAnnotations_comparisons/histone_info_content/intermediateFiles/calculate_avg_posterior/information.fourcells_enhancer.dat",
                      sep='\t')
dpr = pandas.read_csv("/lab/work/arushiv/regulatoryAnnotations_comparisons/histone_info_content/intermediateFiles/calculate_avg_posterior/information.fourcells_promoter.dat",
                     sep='\t')
dpin = pandas.read_csv("intermediateFiles/calculate_avg_posterior/H1.superEnhancers.chr1.promoter.fourcells.avgPosteriors.txt", sep='\t')
dtest = dpin[dpin['end'] == 97029147]
dtest
# Out:
#    chrom     start       end  GM12878        H1  HepG2  K562
# 23  chr1  97024029  97029147      0.0  0.000327    0.0   0.0

# %%
dtest.set_index(['chrom', 'start', 'end'], inplace=True)
dtest
# Out:
#                          GM12878        H1  HepG2  K562
# chrom start    end
# chr1  97024029 97029147      0.0  0.000327    0.0   0.0

# %%
calculate_information(dtest)
# Out:
# Number of features = 4
# max entropy = 2.0
# relative RPKM
#                          GM12878        H1  HepG2  K562
# chrom start    end
# chr1  97024029 97029147      0.0  0.000327    0.0   0.0
# with entropy
#                          GM12878        H1  HepG2  K562   entropy
# chrom start    end
# chr1  97024029 97029147      0.0  0.000327    0.0   0.0  0.003785
# information
#                          GM12878        H1  HepG2  K562  change_in_entropy
# chrom start    end
# chr1  97024029 97029147      0.0  0.000653    0.0   0.0           1.996215
# /home/arushiv/local/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py:357: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# ...

# %%
dpr[(dpr['cell']=="H1") & (dpr['annotation']=="superEnhancers")]
# Out:
#         chrom      start        end  avg_post   GM12878        H1     HepG2  \
# 125184   chr1    6298661    6302179  0.672878  0.000511  0.836632  0.309957
# 125185   chr1   12675558   12697215  0.210265  0.006246  0.009894  0.011470
# 125186   chr1   17215176   17241403  0.280693  0.003381  0.005278  0.004328
# 125187   chr1   17872920   17878963  0.186810  0.003796  1.962901  0.001254
# 125188   chr1   23880646   23895252  0.527780  0.002428  0.003213  0.003480
# 125189   chr1   26737248   26757417  0.212731  0.001037  1.102531  0.001824
# 125190   chr1   27018497   27024717  0.899222  0.000274  0.000254  0.000274
# 125191   chr1   27324282   27337801  0.245330  0.033688  0.348681  0.152058
# 125192   chr1   27883160   27902841  0.197483  0.019703  0.054307  0.125118
# 125193   chr1   33219539   33227576  0.341885  0.017801  0.060429  0.036968
# 125194   chr1   39450820   39468295  0.208878  0.018813  0.021090  0.038887
# ...

# %%
denh_noNorm = pandas.read_csv("/lab/work/arushiv/regulatoryAnnotations_comparisons/histone_info_content/intermediateFiles/calculate_avg_posterior/information_noNorm.fourcells_enhancer.dat",
                      sep='\t')
dpr_noNorm = pandas.read_csv("/lab/work/arushiv/regulatoryAnnotations_comparisons/histone_info_content/intermediateFiles/calculate_avg_posterior/information_noNorm.fourcells_promoter.dat",
                     sep='\t')

# %%
makeGrid(denh_noNorm, 'cell', 'annotation', 'avg_post', 'change_in_entropy', figsize=(15, 12), 
             **{'kind':'hex', 'gridsize':25,'x_label':False, 'y_label':False, 'main_x_label':"Average Enhancer\n State Posteriors", 'main_y_label':"total Info"}, 
             figname="/lab/work/arushiv/regulatoryAnnotations_comparisons/histone_info_content/figures/fig.enhancer_totalinformation_noNorm.pdf")

makeGrid(dpr_noNorm, 'cell', 'annotation', 'avg_post', 'change_in_entropy', figsize=(15, 12), 
             **{'kind':'hex', 'gridsize':25,'x_label':False, 'y_label':False, 'main_x_label':"Average Promoter\n State Posteriors", 'main_y_label':"total Info"}, 
             figname="/lab/work/arushiv/regulatoryAnnotations_comparisons/histone_info_content/figures/fig.promoter_totalinformation_noNorm.pdf")
# Out:
# /home/arushiv/local/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:523: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
dpr_noNorm[(dpr_noNorm['annotation']=="hotRegions") & (dpr_noNorm['cell']=="H1")].head()
# Out:
#        chrom    start      end  avg_post   GM12878        H1     HepG2  \
# 109504  chr1   713812   714404  0.999925  1.907477  1.960866  1.960964
# 109505  chr1   839914   840390  0.986700  0.087787  1.740518  1.763920
# 109506  chr1   934676   936477  0.877330  1.715638  1.563142  1.781667
# 109507  chr1   968187   968960  0.971080  1.400436  1.380982  0.000000
# 109508  chr1  1051188  1052051  0.994767  1.944007  1.941081  1.951227
#
#             K562  change_in_entropy  information cell  annotation
# 109504  1.961013           1.961013     1.960866   H1  hotRegions
# 109505  1.762156           1.763978     1.740518   H1  hotRegions
# 109506  1.781543           1.781703     1.563142   H1  hotRegions
# 109507  0.655820           1.422109     1.380982   H1  hotRegions
# 109508  1.902315           1.951292     1.941081   H1  hotRegions

# %%
pr_post = pandas.read_csv("intermediateFiles/calculate_avg_posterior/H1.hotRegions.chr1.promoter.fourcells.avgPosteriors.txt", sep='\t')
pr_post.head()
# Out:
#   chrom    start      end   GM12878        H1     HepG2      K562
# 0  chr1   713812   714404  0.972700  0.999925  0.999975  1.000000
# 1  chr1   839914   840390  0.049767  0.986700  0.999967  0.998967
# 2  chr1   934676   936477  0.962920  0.877330  0.999980  0.999910
# 3  chr1   968187   968960  0.984760  0.971080  0.000000  0.461160
# 4  chr1  1051188  1052051  0.996267  0.994767  0.999967  0.974900

# %%
t = makeGrid(denh, 'cell', 'annotation', 'avg_post', 'information', figsize=(15, 12), 
             **{'kind':'hex', 'gridsize':25,'x_label':False, 'y_label':False, 'main_x_label':"Average Enhancer\n State Posteriors", 'main_y_label':"Information"}, 
             figname="/lab/work/arushiv/regulatoryAnnotations_comparisons/histone_info_content/figures/fig.enhancer_information_norm.pdf")

#plt.xlabel("Average Posteriors")
# Out:
# /home/arushiv/local/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:523: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
makeGrid(dpr, 'cell', 'annotation', 'avg_post', 'information', figsize=(15, 12), 
         **{'kind':'hex', 'gridsize':25,'x_label':False, 'y_label':False, 'main_x_label':"Average Promoter\nState Posteriors", 'main_y_label':"Information"}, 
         figname="/lab/work/arushiv/regulatoryAnnotations_comparisons/histone_info_content/figures/fig.promoter_information.pdf")
# Out:
# /home/arushiv/local/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:523: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
denh.loc[:,'row'] = "all cells"
dpr.loc[:,'row'] = "all cells"
makeGrid(denh, 'row', 'annotation', 'avg_post', 'information', figsize=(15, 3), 
             **{'x_label':False, 'y_label':False, 'main_x_label':"Average Posterior", 'main_y_label':"Information"}, 
             figname="/lab/work/arushiv/regulatoryAnnotations_comparisons/histone_info_content/figures/fig.enhancer_information_allcells.pdf")
makeGrid(dpr, 'row', 'annotation', 'avg_post', 'information', figsize=(15, 3), 
             **{'x_label':False, 'y_label':False, 'main_x_label':"Average Posterior", 'main_y_label':"Information"}, 
             figname="/lab/work/arushiv/regulatoryAnnotations_comparisons/histone_info_content/figures/fig.promoter_information_allcells.pdf")
# Out:
# /home/arushiv/local/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:523: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
makeGrid(dpr, 'cell', 'annotation', 'avg_post', 'information', figsize=(15, 12), 
         **{'kind':'kde', 'x_label':False, 'y_label':False, 'main_x_label':"Average Promoter\nState Posteriors", 'main_y_label':"Information"}, 
         figname="/lab/work/arushiv/regulatoryAnnotations_comparisons/histone_info_content/figures/fig.promoter_information_kde.pdf")
# Out:
# /home/arushiv/local/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:523: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# /home/arushiv/local/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:967: UserWarning: The following kwargs were not used by contour: 'bins'
#   s)
# /home/arushiv/local/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:967: UserWarning: The following kwargs were not used by contour: 'bins'
#   s)
# /home/arushiv/local/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:967: UserWarning: The following kwargs were not used by contour: 'bins'
#   s)
# ...

# %%
makeGrid(denh, 'cell', 'annotation', 'avg_post', 'information', figsize=(15, 12), 
         **{'kind':'kde', 'x_label':False, 'y_label':False, 'main_x_label':"Average Promoter\nState Posteriors", 'main_y_label':"Information"}, 
         figname="/lab/work/arushiv/regulatoryAnnotations_comparisons/histone_info_content/figures/fig.enhancer_information_kde.pdf")
# Out:
# /home/arushiv/local/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:967: UserWarning: The following kwargs were not used by contour: 'bins'
#   s)
# /home/arushiv/local/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:967: UserWarning: The following kwargs were not used by contour: 'bins'
#   s)
# /home/arushiv/local/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:967: UserWarning: The following kwargs were not used by contour: 'bins'
#   s)
# /home/arushiv/local/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:967: UserWarning: The following kwargs were not used by contour: 'bins'
#   s)
# /home/arushiv/local/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:967: UserWarning: The following kwargs were not used by contour: 'bins'
#   s)
# /home/arushiv/local/anaconda3/lib/python3.6/site-packages/matplotlib/contour.py:967: UserWarning: The following kwargs were not used by contour: 'bins'
#   s)
# ...

# %%
t = makeGrid(denh, 'cell', 'annotation', 'avg_post', 'change_in_entropy', figsize=(15, 12), 
             **{'kind':'hex', 'gridsize':25,'x_label':False, 'y_label':False, 'main_x_label':"Average Enhancer\n State Posteriors", 'main_y_label':"total Info"}, 
             figname="/lab/work/arushiv/regulatoryAnnotations_comparisons/histone_info_content/figures/fig.enhancer_totalinformation.pdf")
# Out:
# /home/arushiv/local/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:523: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
t = makeGrid(dpr, 'cell', 'annotation', 'avg_post', 'change_in_entropy', figsize=(15, 12), 
             **{'kind':'hex', 'gridsize':25,'x_label':False, 'y_label':False, 'main_x_label':"Average Enhancer\n State Posteriors", 'main_y_label':"total Info"}, 
             figname="/lab/work/arushiv/regulatoryAnnotations_comparisons/histone_info_content/figures/fig.promoter_totalinformation.pdf")
# Out:
# /home/arushiv/local/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py:523: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
